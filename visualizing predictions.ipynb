# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from wordcloud import WordCloud

# %%
df=pd.read_csv('/content/drive/MyDrive/tweets_with_predictions.csv')

# %%
df['polarity']= df['polarity'].replace({1:'positive',0:'negative'})
df
# Out:
#                                              clean_text  polarity
# 0                      my sim card does not have signal  positive
# 1       hi heisenberg we are sorry to hear this dm t...  positive
# 2     hi   ive made an mpesa payment to the wrong ti...  negative
# 3                            no phone numbers this time  positive
# 4                                 why are u ignoring uk  positive
# ...                                                 ...       ...
# 9650                     hello kindly activate my mpesa  positive
# 9651  after the split if mpesa and safaricom get lis...  positive
# 9652           state of     in conversation with         positive
# 9653    hey musa please ignore if you have no issue ...  positive
# 9654  coz i didnt have airtime to deal i have called...  positive
#
# [9655 rows x 2 columns]

# %%
#Pie chart
sentiment_counts = df.groupby('polarity').count()
sizes = sentiment_counts['clean_text']
plt.pie(sizes, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Sentiment Analysis')
plt.show()

# %%
# Group the data by polarity
polarity_groups = df.groupby('polarity')

# Create a word cloud for each polarity
for polarity, group in polarity_groups:
    text = ' '.join(group['clean_text'])
    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color='white').generate(text)
    plt.figure()
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(polarity)
plt.show()

# %%
grouped_data = df.groupby('polarity')['clean_text'].count().reset_index()

# create the bar chart using seaborn
sns.barplot(x='polarity', y='clean_text', data=grouped_data)

# set the title and labels
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Count')

# show the chart
plt.show()
